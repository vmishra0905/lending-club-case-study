# %%
#read data from .csv
import pandas as pd
pd.set_option('display.max_columns',None)
loan_data=pd.read_csv(r'C:\Users\VijayMishra\Downloads\loan\loan.csv',low_memory= False)
loan_data.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade                  emp_title emp_length  \
# 0   10.65%       162.87     B        B2                        NaN  10+ years
# 1   15.27%        59.83     C        C4                      Ryder   < 1 year
# 2   15.96%        84.33     C        C5                        NaN  10+ years
# 3   13.49%       339.31     C        C1        AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5   University Medical Group     1 year
# 5    7.90%       156.46     A        A4       Veolia Transportaton    3 years
# 6   15.96%       170.08     C        C5  Southern Star Photography    8 years
# 7   18.64%       109.43     E        E1            MKC Accounting     9 years
# 8   21.28%       152.39     F        F2                        NaN    4 years
# 9   12.69%       121.45     B        B5                  Starbucks   < 1 year
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0           RENT     24000.0            Verified  Dec-11   Fully Paid
# 1           RENT     30000.0     Source Verified  Dec-11  Charged Off
# 2           RENT     12252.0        Not Verified  Dec-11   Fully Paid
# 3           RENT     49200.0     Source Verified  Dec-11   Fully Paid
# 4           RENT     80000.0     Source Verified  Dec-11      Current
# 5           RENT     36000.0     Source Verified  Dec-11   Fully Paid
# 6           RENT     47004.0        Not Verified  Dec-11   Fully Paid
# 7           RENT     48000.0     Source Verified  Dec-11   Fully Paid
# 8            OWN     40000.0     Source Verified  Dec-11  Charged Off
# 9           RENT     15000.0            Verified  Dec-11  Charged Off
#
#   pymnt_plan                                                url  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...
# 1          n  https://lendingclub.com/browse/loanDetail.acti...
# 2          n  https://lendingclub.com/browse/loanDetail.acti...
# 3          n  https://lendingclub.com/browse/loanDetail.acti...
# 4          n  https://lendingclub.com/browse/loanDetail.acti...
# 5          n  https://lendingclub.com/browse/loanDetail.acti...
# 6          n  https://lendingclub.com/browse/loanDetail.acti...
# 7          n  https://lendingclub.com/browse/loanDetail.acti...
# 8          n  https://lendingclub.com/browse/loanDetail.acti...
# 9          n  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                 desc             purpose  \
# 0    Borrower added on 12/22/11 > I need to upgra...         credit_card
# 1    Borrower added on 12/22/11 > I plan to use t...                 car
# 2                                                NaN      small_business
# 3    Borrower added on 12/21/11 > to pay for prop...               other
# 4    Borrower added on 12/21/11 > I plan on combi...               other
# 5                                                NaN             wedding
# 6    Borrower added on 12/18/11 > I am planning o...  debt_consolidation
# 7    Borrower added on 12/16/11 > Downpayment for...                 car
# 8    Borrower added on 12/21/11 > I own a small h...      small_business
# 9    Borrower added on 12/16/11 > I'm trying to b...               other
#
#                                    title zip_code addr_state    dti  \
# 0                               Computer    860xx         AZ  27.65
# 1                                   bike    309xx         GA   1.00
# 2                   real estate business    606xx         IL   8.72
# 3                               personel    917xx         CA  20.00
# 4                               Personal    972xx         OR  17.94
# 5  My wedding loan I promise to pay back    852xx         AZ  11.20
# 6                                   Loan    280xx         NC  23.51
# 7                        Car Downpayment    900xx         CA   5.35
# 8   Expand Business & Buy Debt Portfolio    958xx         CA   5.55
# 9            Building my credit history.    774xx         TX  18.08
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0           Jan-85               1                     NaN
# 1            0           Apr-99               5                     NaN
# 2            0           Nov-01               2                     NaN
# 3            0           Feb-96               1                    35.0
# 4            0           Jan-96               0                    38.0
# 5            0           Nov-04               3                     NaN
# 6            0           Jul-05               1                     NaN
# 7            0           Jan-07               2                     NaN
# 8            0           Apr-04               2                     NaN
# 9            0           Sep-04               0                     NaN
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         3        0      13648     83.70%          9
# 1                     NaN         3        0       1687      9.40%          4
# 2                     NaN         2        0       2956     98.50%         10
# 3                     NaN        10        0       5598        21%         37
# 4                     NaN        15        0      27783     53.90%         38
# 5                     NaN         9        0       7963     28.30%         12
# 6                     NaN         7        0      17726     85.60%         11
# 7                     NaN         4        0       8221     87.50%          4
# 8                     NaN        11        0       5210     32.60%         13
# 9                     NaN         2        0       9279     36.50%          3
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   f       0.00           0.00   5863.155187
# 1                   f       0.00           0.00   1008.710000
# 2                   f       0.00           0.00   3005.666844
# 3                   f       0.00           0.00  12231.890000
# 4                   f     524.06         524.06   3513.330000
# 5                   f       0.00           0.00   5632.210000
# 6                   f       0.00           0.00  10110.840000
# 7                   f       0.00           0.00   3939.135294
# 8                   f       0.00           0.00    646.020000
# 9                   f       0.00           0.00   1476.190000
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          5833.84          5000.00         863.16                0.00
# 1          1008.71           456.46         435.17                0.00
# 2          3005.67          2400.00         605.67                0.00
# 3         12231.89         10000.00        2214.92               16.97
# 4          3513.33          2475.94        1037.39                0.00
# 5          5632.21          5000.00         632.21                0.00
# 6         10110.84          6985.61        3125.23                0.00
# 7          3939.14          3000.00         939.14                0.00
# 8           646.02           162.02         294.94                0.00
# 9          1469.34           673.48         533.42                0.00
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0        0.00                     0.00       Jan-15           171.62
# 1      117.08                     1.11       Apr-13           119.66
# 2        0.00                     0.00       Jun-14           649.91
# 3        0.00                     0.00       Jan-15           357.48
# 4        0.00                     0.00       May-16            67.79
# 5        0.00                     0.00       Jan-15           161.03
# 6        0.00                     0.00       May-16          1313.76
# 7        0.00                     0.00       Jan-15           111.34
# 8      189.06                     2.09       Apr-12           152.39
# 9      269.29                     2.52       Nov-12           121.45
#
#   next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0          NaN             May-16                         0.0
# 1          NaN             Sep-13                         0.0
# 2          NaN             May-16                         0.0
# 3          NaN             Apr-16                         0.0
# 4       Jun-16             May-16                         0.0
# 5          NaN             Jan-16                         0.0
# 6          NaN             May-16                         0.0
# 7          NaN             Dec-14                         0.0
# 8          NaN             Aug-12                         0.0
# 9          NaN             Mar-13                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN            1       INDIVIDUAL
# 1                          NaN            1       INDIVIDUAL
# 2                          NaN            1       INDIVIDUAL
# 3                          NaN            1       INDIVIDUAL
# 4                          NaN            1       INDIVIDUAL
# 5                          NaN            1       INDIVIDUAL
# 6                          NaN            1       INDIVIDUAL
# 7                          NaN            1       INDIVIDUAL
# 8                          NaN            1       INDIVIDUAL
# 9                          NaN            1       INDIVIDUAL
#
#    annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                        NaN               0
# 1               NaN        NaN                        NaN               0
# 2               NaN        NaN                        NaN               0
# 3               NaN        NaN                        NaN               0
# 4               NaN        NaN                        NaN               0
# 5               NaN        NaN                        NaN               0
# 6               NaN        NaN                        NaN               0
# 7               NaN        NaN                        NaN               0
# 8               NaN        NaN                        NaN               0
# 9               NaN        NaN                        NaN               0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 0           NaN          NaN          NaN         NaN          NaN
# 1           NaN          NaN          NaN         NaN          NaN
# 2           NaN          NaN          NaN         NaN          NaN
# 3           NaN          NaN          NaN         NaN          NaN
# 4           NaN          NaN          NaN         NaN          NaN
# 5           NaN          NaN          NaN         NaN          NaN
# 6           NaN          NaN          NaN         NaN          NaN
# 7           NaN          NaN          NaN         NaN          NaN
# 8           NaN          NaN          NaN         NaN          NaN
# 9           NaN          NaN          NaN         NaN          NaN
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          NaN                 NaN           NaN      NaN          NaN
# 1          NaN                 NaN           NaN      NaN          NaN
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          NaN                 NaN           NaN      NaN          NaN
# 4          NaN                 NaN           NaN      NaN          NaN
# 5          NaN                 NaN           NaN      NaN          NaN
# 6          NaN                 NaN           NaN      NaN          NaN
# 7          NaN                 NaN           NaN      NaN          NaN
# 8          NaN                 NaN           NaN      NaN          NaN
# 9          NaN                 NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          NaN         NaN       NaN               NaN     NaN          NaN
# 1          NaN         NaN       NaN               NaN     NaN          NaN
# 2          NaN         NaN       NaN               NaN     NaN          NaN
# 3          NaN         NaN       NaN               NaN     NaN          NaN
# 4          NaN         NaN       NaN               NaN     NaN          NaN
# 5          NaN         NaN       NaN               NaN     NaN          NaN
# 6          NaN         NaN       NaN               NaN     NaN          NaN
# 7          NaN         NaN       NaN               NaN     NaN          NaN
# 8          NaN         NaN       NaN               NaN     NaN          NaN
# 9          NaN         NaN       NaN               NaN     NaN          NaN
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           NaN                   NaN          NaN             NaN      NaN
# 1           NaN                   NaN          NaN             NaN      NaN
# 2           NaN                   NaN          NaN             NaN      NaN
# 3           NaN                   NaN          NaN             NaN      NaN
# 4           NaN                   NaN          NaN             NaN      NaN
# 5           NaN                   NaN          NaN             NaN      NaN
# 6           NaN                   NaN          NaN             NaN      NaN
# 7           NaN                   NaN          NaN             NaN      NaN
# 8           NaN                   NaN          NaN             NaN      NaN
# 9           NaN                   NaN          NaN             NaN      NaN
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0            0                 NaN
# 1                       0.0            0                 NaN
# 2                       0.0            0                 NaN
# 3                       0.0            0                 NaN
# 4                       0.0            0                 NaN
# 5                       0.0            0                 NaN
# 6                       0.0            0                 NaN
# 7                       0.0            0                 NaN
# 8                       0.0            0                 NaN
# 9                       0.0            0                 NaN
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                   NaN                    NaN             NaN       NaN
# 1                   NaN                    NaN             NaN       NaN
# 2                   NaN                    NaN             NaN       NaN
# 3                   NaN                    NaN             NaN       NaN
# 4                   NaN                    NaN             NaN       NaN
# 5                   NaN                    NaN             NaN       NaN
# 6                   NaN                    NaN             NaN       NaN
# 7                   NaN                    NaN             NaN       NaN
# 8                   NaN                    NaN             NaN       NaN
# 9                   NaN                    NaN             NaN       NaN
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                       NaN                    NaN
# 1                   NaN                       NaN                    NaN
# 2                   NaN                       NaN                    NaN
# 3                   NaN                       NaN                    NaN
# 4                   NaN                       NaN                    NaN
# 5                   NaN                       NaN                    NaN
# 6                   NaN                       NaN                    NaN
# 7                   NaN                       NaN                    NaN
# 8                   NaN                       NaN                    NaN
# 9                   NaN                       NaN                    NaN
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                    NaN             NaN
# 1                             NaN                    NaN             NaN
# 2                             NaN                    NaN             NaN
# 3                             NaN                    NaN             NaN
# 4                             NaN                    NaN             NaN
# 5                             NaN                    NaN             NaN
# 6                             NaN                    NaN             NaN
# 7                             NaN                    NaN             NaN
# 8                             NaN                    NaN             NaN
# 9                             NaN                    NaN             NaN
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              NaN          NaN        NaN        NaN            NaN
# 1              NaN          NaN        NaN        NaN            NaN
# 2              NaN          NaN        NaN        NaN            NaN
# 3              NaN          NaN        NaN        NaN            NaN
# 4              NaN          NaN        NaN        NaN            NaN
# 5              NaN          NaN        NaN        NaN            NaN
# 6              NaN          NaN        NaN        NaN            NaN
# 7              NaN          NaN        NaN        NaN            NaN
# 8              NaN          NaN        NaN        NaN            NaN
# 9              NaN          NaN        NaN        NaN            NaN
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            NaN                  NaN       NaN               NaN
# 1            NaN                  NaN       NaN               NaN
# 2            NaN                  NaN       NaN               NaN
# 3            NaN                  NaN       NaN               NaN
# 4            NaN                  NaN       NaN               NaN
# 5            NaN                  NaN       NaN               NaN
# 6            NaN                  NaN       NaN               NaN
# 7            NaN                  NaN       NaN               NaN
# 8            NaN                  NaN       NaN               NaN
# 9            NaN                  NaN       NaN               NaN
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           NaN                 NaN                 NaN             NaN
# 1           NaN                 NaN                 NaN             NaN
# 2           NaN                 NaN                 NaN             NaN
# 3           NaN                 NaN                 NaN             NaN
# 4           NaN                 NaN                 NaN             NaN
# 5           NaN                 NaN                 NaN             NaN
# 6           NaN                 NaN                 NaN             NaN
# 7           NaN                 NaN                 NaN             NaN
# 8           NaN                 NaN                 NaN             NaN
# 9           NaN                 NaN                 NaN             NaN
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   0.0        0.0              NaN
# 1               NaN                   0.0        0.0              NaN
# 2               NaN                   0.0        0.0              NaN
# 3               NaN                   0.0        0.0              NaN
# 4               NaN                   0.0        0.0              NaN
# 5               NaN                   0.0        0.0              NaN
# 6               NaN                   0.0        0.0              NaN
# 7               NaN                   0.0        0.0              NaN
# 8               NaN                   0.0        0.0              NaN
# 9               NaN                   0.0        0.0              NaN
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit
# 0                NaN             NaN                         NaN
# 1                NaN             NaN                         NaN
# 2                NaN             NaN                         NaN
# 3                NaN             NaN                         NaN
# 4                NaN             NaN                         NaN
# 5                NaN             NaN                         NaN
# 6                NaN             NaN                         NaN
# 7                NaN             NaN                         NaN
# 8                NaN             NaN                         NaN
# 9                NaN             NaN                         NaN

# %%
##checking for NULL columns which is not needed
#for col in loan_data.columns:
 #   print(col,loan_data[col].isna().sum())

# %%
#to check if allthe values are NULL in columns
cols_null_val_perctg = loan_data.isnull().mean()*100
cols_null_val_perctg
# Out:
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.098195
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %%
cols_zero_null_val_perctg = cols_null_val_perctg[cols_null_val_perctg < 30].index

cols_zero_null_val_perctg
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'tax_liens'],
#       dtype='object')

# %%
loan_data =loan_data[cols_zero_null_val_perctg]

# %%
loan_data= loan_data[cols_zero_null_val_perctg]

non_neg_cols = loan_data.nunique()

loan_data = loan_data[non_neg_cols[non_neg_cols > 1].index]

loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       39717 non-null  int64
#  1   member_id                39717 non-null  int64
#  2   loan_amnt                39717 non-null  int64
#  3   funded_amnt              39717 non-null  int64
#  4   funded_amnt_inv          39717 non-null  float64
#  5   term                     39717 non-null  object
#  6   int_rate                 39717 non-null  object
#  7   installment              39717 non-null  float64
#  8   grade                    39717 non-null  object
#  9   sub_grade                39717 non-null  object
#  10  emp_title                37258 non-null  object
#  11  emp_length               38642 non-null  object
#  12  home_ownership           39717 non-null  object
#  13  annual_inc               39717 non-null  float64
#  14  verification_status      39717 non-null  object
#  15  issue_d                  39717 non-null  object
#  16  loan_status              39717 non-null  object
#  17  url                      39717 non-null  object
#  18  purpose                  39717 non-null  object
#  19  title                    39706 non-null  object
#  20  zip_code                 39717 non-null  object
#  21  addr_state               39717 non-null  object
#  22  dti                      39717 non-null  float64
#  23  delinq_2yrs              39717 non-null  int64
#  24  earliest_cr_line         39717 non-null  object
#  25  inq_last_6mths           39717 non-null  int64
#  26  open_acc                 39717 non-null  int64
#  27  pub_rec                  39717 non-null  int64
#  28  revol_bal                39717 non-null  int64
#  29  revol_util               39667 non-null  object
#  30  total_acc                39717 non-null  int64
#  31  out_prncp                39717 non-null  float64
#  32  out_prncp_inv            39717 non-null  float64
#  33  total_pymnt              39717 non-null  float64
#  34  total_pymnt_inv          39717 non-null  float64
#  35  total_rec_prncp          39717 non-null  float64
#  36  total_rec_int            39717 non-null  float64
#  37  total_rec_late_fee       39717 non-null  float64
#  38  recoveries               39717 non-null  float64
#  39  collection_recovery_fee  39717 non-null  float64
#  40  last_pymnt_d             39646 non-null  object
#  41  last_pymnt_amnt          39717 non-null  float64
#  42  last_credit_pull_d       39715 non-null  object
#  43  pub_rec_bankruptcies     39020 non-null  float64
# dtypes: float64(15), int64(10), object(19)
# memory usage: 13.3+ MB

# %%
loan_data.isna().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                  2459
# emp_length                 1075
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# url                           0
# purpose                       0
# title                        11
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                   50
# total_acc                     0
# out_prncp                     0
# out_prncp_inv                 0
# total_pymnt                   0
# total_pymnt_inv               0
# total_rec_prncp               0
# total_rec_int                 0
# total_rec_late_fee            0
# recoveries                    0
# collection_recovery_fee       0
# last_pymnt_d                 71
# last_pymnt_amnt               0
# last_credit_pull_d            2
# pub_rec_bankruptcies        697
# dtype: int64

# %%
loan_data['revol_util'].describe()
# Out:
# count     39667
# unique     1089
# top          0%
# freq        977
# Name: revol_util, dtype: object

# %%
loan_data['revol_util']
# Out:
# 0        83.70%
# 1         9.40%
# 2        98.50%
# 3           21%
# 4        53.90%
#           ...
# 39712    13.10%
# 39713    26.90%
# 39714    19.40%
# 39715     0.70%
# 39716    51.50%
# Name: revol_util, Length: 39717, dtype: object

# %%
loan_data['revol_util'] =loan_data['revol_util'].str.replace('%','')

# %%
loan_data['revol_util']=loan_data['revol_util'].astype('float')
loan_data['revol_util']
# Out:
# 0        83.7
# 1         9.4
# 2        98.5
# 3        21.0
# 4        53.9
#          ...
# 39712    13.1
# 39713    26.9
# 39714    19.4
# 39715     0.7
# 39716    51.5
# Name: revol_util, Length: 39717, dtype: float64

# %%
loan_data['revol_util'] = loan_data['revol_util'].fillna(loan_data['revol_util'].mean())

# %%
loan_data['emp_title']
# Out:
# 0                               NaN
# 1                             Ryder
# 2                               NaN
# 3               AIR RESOURCES BOARD
# 4          University Medical Group
#                     ...
# 39712               FiSite Research
# 39713    Squarewave Solutions, Ltd.
# 39714                           NaN
# 39715                           NaN
# 39716              Evergreen Center
# Name: emp_title, Length: 39717, dtype: object

# %%
#Remove percenetage from int_rate columns and revol_util
loan_data['int_rate'] =loan_data['int_rate'].str.replace('%','')
loan_data['int_rate']
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 39717, dtype: object

# %%
loan_data['int_rate'].isna().sum()
# Out:
# 0

# %%
#Remove percenetage from int_rate columns and revol_util
loan_data['int_rate'] =loan_data['int_rate'].astype('float')

# %%
#remove MOnths from term
def modify_term(term):
    return term.split()[0]
loan_data['term'] =loan_data['term'].apply(modify_term)

# %%
loan_data['term'] =loan_data['term'].astype('int32')
#Convert thedata type term to int
#loan_data2['term']=loan_data2['term'].astype('int32')

# %%
loan_data['pub_rec_bankruptcies'].describe()
# Out:
# count    39020.000000
# mean         0.043260
# std          0.204324
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          2.000000
# Name: pub_rec_bankruptcies, dtype: float64

# %%
loan_data =loan_data.drop('pub_rec_bankruptcies',axis=1)

# %%
loan_data
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  \
# 0       36 months   10.65%       162.87     B        B2
# 1       60 months   15.27%        59.83     C        C4
# 2       36 months   15.96%        84.33     C        C5
# 3       36 months   13.49%       339.31     C        C1
# 4       60 months   12.69%        67.79     B        B5
# ...           ...      ...          ...   ...       ...
# 39712   36 months    8.07%        78.42     A        A4
# 39713   36 months   10.28%       275.38     C        C1
# 39714   36 months    8.07%       156.84     A        A4
# 39715   36 months    7.43%       155.38     A        A2
# 39716   36 months   13.75%       255.43     E        E2
#
#                         emp_title emp_length home_ownership  annual_inc  \
# 0                             NaN  10+ years           RENT     24000.0
# 1                           Ryder   < 1 year           RENT     30000.0
# 2                             NaN  10+ years           RENT     12252.0
# 3             AIR RESOURCES BOARD  10+ years           RENT     49200.0
# 4        University Medical Group     1 year           RENT     80000.0
# ...                           ...        ...            ...         ...
# 39712             FiSite Research    4 years       MORTGAGE    110000.0
# 39713  Squarewave Solutions, Ltd.    3 years           RENT     18000.0
# 39714                         NaN   < 1 year       MORTGAGE    100000.0
# 39715                         NaN   < 1 year       MORTGAGE    200000.0
# 39716            Evergreen Center   < 1 year            OWN     22000.0
#
#       verification_status issue_d  loan_status  \
# 0                Verified  Dec-11   Fully Paid
# 1         Source Verified  Dec-11  Charged Off
# 2            Not Verified  Dec-11   Fully Paid
# 3         Source Verified  Dec-11   Fully Paid
# 4         Source Verified  Dec-11      Current
# ...                   ...     ...          ...
# 39712        Not Verified  Jul-07   Fully Paid
# 39713        Not Verified  Jul-07   Fully Paid
# 39714        Not Verified  Jul-07   Fully Paid
# 39715        Not Verified  Jul-07   Fully Paid
# 39716        Not Verified  Jun-07   Fully Paid
#
#                                                      url             purpose  \
# 0      https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 1      https://lendingclub.com/browse/loanDetail.acti...                 car
# 2      https://lendingclub.com/browse/loanDetail.acti...      small_business
# 3      https://lendingclub.com/browse/loanDetail.acti...               other
# 4      https://lendingclub.com/browse/loanDetail.acti...               other
# ...                                                  ...                 ...
# 39712  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 39713  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 39714  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 39715  https://lendingclub.com/browse/loanDetail.acti...               other
# 39716  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
#                            title zip_code addr_state    dti  delinq_2yrs  \
# 0                       Computer    860xx         AZ  27.65            0
# 1                           bike    309xx         GA   1.00            0
# 2           real estate business    606xx         IL   8.72            0
# 3                       personel    917xx         CA  20.00            0
# 4                       Personal    972xx         OR  17.94            0
# ...                          ...      ...        ...    ...          ...
# 39712           Home Improvement    802xx         CO  11.33            0
# 39713  Retiring credit card debt    274xx         NC   6.40            1
# 39714     MBA Loan Consolidation    017xx         MA   2.30            0
# 39715                   JAL Loan    208xx         MD   3.72            0
# 39716         Consolidation Loan    027xx         MA  14.29            1
#
#       earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  \
# 0               Jan-85               1         3        0      13648
# 1               Apr-99               5         3        0       1687
# 2               Nov-01               2         2        0       2956
# 3               Feb-96               1        10        0       5598
# 4               Jan-96               0        15        0      27783
# ...                ...             ...       ...      ...        ...
# 39712           Nov-90               0        13        0       7274
# 39713           Dec-86               1         6        0       8847
# 39714           Oct-98               0        11        0       9698
# 39715           Nov-88               0        17        0      85607
# 39716           Oct-03               0         7        0       4175
#
#       revol_util  total_acc  out_prncp  out_prncp_inv   total_pymnt  \
# 0         83.70%          9       0.00           0.00   5863.155187
# 1          9.40%          4       0.00           0.00   1008.710000
# 2         98.50%         10       0.00           0.00   3005.666844
# 3            21%         37       0.00           0.00  12231.890000
# 4         53.90%         38     524.06         524.06   3513.330000
# ...          ...        ...        ...            ...           ...
# 39712     13.10%         40       0.00           0.00   2822.969293
# 39713     26.90%          9       0.00           0.00   9913.491822
# 39714     19.40%         20       0.00           0.00   5272.161128
# 39715      0.70%         26       0.00           0.00   5174.198551
# 39716     51.50%          8       0.00           0.00   9195.263334
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0              5833.84          5000.00         863.16                0.00
# 1              1008.71           456.46         435.17                0.00
# 2              3005.67          2400.00         605.67                0.00
# 3             12231.89         10000.00        2214.92               16.97
# 4              3513.33          2475.94        1037.39                0.00
# ...                ...              ...            ...                 ...
# 39712          1213.88          2500.00         322.97                0.00
# 39713          1020.51          8500.00        1413.49                0.00
# 39714          1397.12          5000.00         272.16                0.00
# 39715           672.66          5000.00         174.20                0.00
# 39716           980.83          7500.00        1695.26                0.00
#
#        recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0            0.00                     0.00       Jan-15           171.62
# 1          117.08                     1.11       Apr-13           119.66
# 2            0.00                     0.00       Jun-14           649.91
# 3            0.00                     0.00       Jan-15           357.48
# 4            0.00                     0.00       May-16            67.79
# ...           ...                      ...          ...              ...
# 39712        0.00                     0.00       Jul-10            80.90
# 39713        0.00                     0.00       Jul-10           281.94
# 39714        0.00                     0.00       Apr-08             0.00
# 39715        0.00                     0.00       Jan-08             0.00
# 39716        0.00                     0.00       Jun-10           256.59
#
#       last_credit_pull_d
# 0                 May-16
# 1                 Sep-13
# 2                 May-16
# 3                 Apr-16
# 4                 May-16
# ...                  ...
# 39712             Jun-10
# 39713             Jul-10
# 39714             Jun-07
# 39715             Jun-07
# 39716             Jun-10
#
# [39717 rows x 43 columns]

# %%
num_cols = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'annual_inc','dti', 'revol_bal', 'revol_util', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 
            'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'pub_rec_bankruptcies']
cat_cols = ['term', 'grade', 'sub_grade', 'emp_length', 'home_ownership', 'verification_status', 'loan_status', 'purpose', 'title', 'zip_code', 'addr_state', 'delinq_2yrs', 
            'inq_last_6mths', 'open_acc', 'pub_rec', 'total_acc', ]
date_cols = ['issue_d', 'last_pymnt_d', 'last_credit_pull_d', 'earliest_cr_line']
extra_cols = ['id', 'member_id','emp_title', 'pymnt_plan', 'url', '']

# %%
loan_data[num_cols]
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  annual_inc int_rate  \
# 0           5000         5000           4975.0     24000.0   10.65%
# 1           2500         2500           2500.0     30000.0   15.27%
# 2           2400         2400           2400.0     12252.0   15.96%
# 3          10000        10000          10000.0     49200.0   13.49%
# 4           3000         3000           3000.0     80000.0   12.69%
# ...          ...          ...              ...         ...      ...
# 39712       2500         2500           1075.0    110000.0    8.07%
# 39713       8500         8500            875.0     18000.0   10.28%
# 39714       5000         5000           1325.0    100000.0    8.07%
# 39715       5000         5000            650.0    200000.0    7.43%
# 39716       7500         7500            800.0     22000.0   13.75%
#
#        revol_bal revol_util  total_acc   total_pymnt  total_pymnt_inv  \
# 0          13648     83.70%          9   5863.155187          5833.84
# 1           1687      9.40%          4   1008.710000          1008.71
# 2           2956     98.50%         10   3005.666844          3005.67
# 3           5598        21%         37  12231.890000         12231.89
# 4          27783     53.90%         38   3513.330000          3513.33
# ...          ...        ...        ...           ...              ...
# 39712       7274     13.10%         40   2822.969293          1213.88
# 39713       8847     26.90%          9   9913.491822          1020.51
# 39714       9698     19.40%         20   5272.161128          1397.12
# 39715      85607      0.70%         26   5174.198551           672.66
# 39716       4175     51.50%          8   9195.263334           980.83
#
#        total_rec_int
# 0             863.16
# 1             435.17
# 2             605.67
# 3            2214.92
# 4            1037.39
# ...              ...
# 39712         322.97
# 39713        1413.49
# 39714         272.16
# 39715         174.20
# 39716        1695.26
#
# [39717 rows x 11 columns]

# %%
loan_data[cat_cols]
# Out:
#              term  installment home_ownership  loan_status  \
# 0       36 months       162.87           RENT   Fully Paid
# 1       60 months        59.83           RENT  Charged Off
# 2       36 months        84.33           RENT   Fully Paid
# 3       36 months       339.31           RENT   Fully Paid
# 4       60 months        67.79           RENT      Current
# ...           ...          ...            ...          ...
# 39712   36 months        78.42       MORTGAGE   Fully Paid
# 39713   36 months       275.38           RENT   Fully Paid
# 39714   36 months       156.84       MORTGAGE   Fully Paid
# 39715   36 months       155.38       MORTGAGE   Fully Paid
# 39716   36 months       255.43            OWN   Fully Paid
#
#                   purpose verification_status
# 0             credit_card            Verified
# 1                     car     Source Verified
# 2          small_business        Not Verified
# 3                   other     Source Verified
# 4                   other     Source Verified
# ...                   ...                 ...
# 39712    home_improvement        Not Verified
# 39713         credit_card        Not Verified
# 39714  debt_consolidation        Not Verified
# 39715               other        Not Verified
# 39716  debt_consolidation        Not Verified
#
# [39717 rows x 6 columns]

# %%
#drop all the columns where majority is NAN

# %%
loan_data.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'url', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d'],
#       dtype='object')

# %%
#Columns which is not helpfulfor EDA 
drop_columns_new=["url","emp_title","title","zip_code","addr_state","dti","pub_rec","issue_d","last_credit_pull_d","emp_length","earliest_cr_line"]

loan_data[drop_columns_new]
# Out:
#                                                      url  \
# 0      https://lendingclub.com/browse/loanDetail.acti...
# 1      https://lendingclub.com/browse/loanDetail.acti...
# 2      https://lendingclub.com/browse/loanDetail.acti...
# 3      https://lendingclub.com/browse/loanDetail.acti...
# 4      https://lendingclub.com/browse/loanDetail.acti...
# ...                                                  ...
# 39712  https://lendingclub.com/browse/loanDetail.acti...
# 39713  https://lendingclub.com/browse/loanDetail.acti...
# 39714  https://lendingclub.com/browse/loanDetail.acti...
# 39715  https://lendingclub.com/browse/loanDetail.acti...
# 39716  https://lendingclub.com/browse/loanDetail.acti...
#
#                         emp_title                      title zip_code  \
# 0                             NaN                   Computer    860xx
# 1                           Ryder                       bike    309xx
# 2                             NaN       real estate business    606xx
# 3             AIR RESOURCES BOARD                   personel    917xx
# 4        University Medical Group                   Personal    972xx
# ...                           ...                        ...      ...
# 39712             FiSite Research           Home Improvement    802xx
# 39713  Squarewave Solutions, Ltd.  Retiring credit card debt    274xx
# 39714                         NaN     MBA Loan Consolidation    017xx
# 39715                         NaN                   JAL Loan    208xx
# 39716            Evergreen Center         Consolidation Loan    027xx
#
#       addr_state    dti  pub_rec issue_d last_credit_pull_d emp_length  \
# 0             AZ  27.65        0  Dec-11             May-16  10+ years
# 1             GA   1.00        0  Dec-11             Sep-13   < 1 year
# 2             IL   8.72        0  Dec-11             May-16  10+ years
# 3             CA  20.00        0  Dec-11             Apr-16  10+ years
# 4             OR  17.94        0  Dec-11             May-16     1 year
# ...          ...    ...      ...     ...                ...        ...
# 39712         CO  11.33        0  Jul-07             Jun-10    4 years
# 39713         NC   6.40        0  Jul-07             Jul-10    3 years
# 39714         MA   2.30        0  Jul-07             Jun-07   < 1 year
# 39715         MD   3.72        0  Jul-07             Jun-07   < 1 year
# 39716         MA  14.29        0  Jun-07             Jun-10   < 1 year
#
#       earliest_cr_line
# 0               Jan-85
# 1               Apr-99
# 2               Nov-01
# 3               Feb-96
# 4               Jan-96
# ...                ...
# 39712           Nov-90
# 39713           Dec-86
# 39714           Oct-98
# 39715           Nov-88
# 39716           Oct-03
#
# [39717 rows x 11 columns]

# %%
#dropped some more columns which is not useful

loan_data1=loan_data.drop(columns=drop_columns_new)
loan_data1
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade home_ownership  \
# 0       36 months   10.65%       162.87     B        B2           RENT
# 1       60 months   15.27%        59.83     C        C4           RENT
# 2       36 months   15.96%        84.33     C        C5           RENT
# 3       36 months   13.49%       339.31     C        C1           RENT
# 4       60 months   12.69%        67.79     B        B5           RENT
# ...           ...      ...          ...   ...       ...            ...
# 39712   36 months    8.07%        78.42     A        A4       MORTGAGE
# 39713   36 months   10.28%       275.38     C        C1           RENT
# 39714   36 months    8.07%       156.84     A        A4       MORTGAGE
# 39715   36 months    7.43%       155.38     A        A2       MORTGAGE
# 39716   36 months   13.75%       255.43     E        E2            OWN
#
#        annual_inc verification_status  loan_status             purpose  \
# 0         24000.0            Verified   Fully Paid         credit_card
# 1         30000.0     Source Verified  Charged Off                 car
# 2         12252.0        Not Verified   Fully Paid      small_business
# 3         49200.0     Source Verified   Fully Paid               other
# 4         80000.0     Source Verified      Current               other
# ...           ...                 ...          ...                 ...
# 39712    110000.0        Not Verified   Fully Paid    home_improvement
# 39713     18000.0        Not Verified   Fully Paid         credit_card
# 39714    100000.0        Not Verified   Fully Paid  debt_consolidation
# 39715    200000.0        Not Verified   Fully Paid               other
# 39716     22000.0        Not Verified   Fully Paid  debt_consolidation
#
#        delinq_2yrs  inq_last_6mths  open_acc  revol_bal revol_util  total_acc  \
# 0                0               1         3      13648     83.70%          9
# 1                0               5         3       1687      9.40%          4
# 2                0               2         2       2956     98.50%         10
# 3                0               1        10       5598        21%         37
# 4                0               0        15      27783     53.90%         38
# ...            ...             ...       ...        ...        ...        ...
# 39712            0               0        13       7274     13.10%         40
# 39713            1               1         6       8847     26.90%          9
# 39714            0               0        11       9698     19.40%         20
# 39715            0               0        17      85607      0.70%         26
# 39716            1               0         7       4175     51.50%          8
#
#        out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  \
# 0           0.00           0.00   5863.155187          5833.84
# 1           0.00           0.00   1008.710000          1008.71
# 2           0.00           0.00   3005.666844          3005.67
# 3           0.00           0.00  12231.890000         12231.89
# 4         524.06         524.06   3513.330000          3513.33
# ...          ...            ...           ...              ...
# 39712       0.00           0.00   2822.969293          1213.88
# 39713       0.00           0.00   9913.491822          1020.51
# 39714       0.00           0.00   5272.161128          1397.12
# 39715       0.00           0.00   5174.198551           672.66
# 39716       0.00           0.00   9195.263334           980.83
#
#        total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 0              5000.00         863.16                0.00        0.00
# 1               456.46         435.17                0.00      117.08
# 2              2400.00         605.67                0.00        0.00
# 3             10000.00        2214.92               16.97        0.00
# 4              2475.94        1037.39                0.00        0.00
# ...                ...            ...                 ...         ...
# 39712          2500.00         322.97                0.00        0.00
# 39713          8500.00        1413.49                0.00        0.00
# 39714          5000.00         272.16                0.00        0.00
# 39715          5000.00         174.20                0.00        0.00
# 39716          7500.00        1695.26                0.00        0.00
#
#        collection_recovery_fee last_pymnt_d  last_pymnt_amnt
# 0                         0.00       Jan-15           171.62
# 1                         1.11       Apr-13           119.66
# 2                         0.00       Jun-14           649.91
# 3                         0.00       Jan-15           357.48
# 4                         0.00       May-16            67.79
# ...                        ...          ...              ...
# 39712                     0.00       Jul-10            80.90
# 39713                     0.00       Jul-10           281.94
# 39714                     0.00       Apr-08             0.00
# 39715                     0.00       Jan-08             0.00
# 39716                     0.00       Jun-10           256.59
#
# [39717 rows x 32 columns]

# %%
#These will columns will be used for EDA 
filt_num_cols = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'annual_inc', 'revol_bal', 'revol_util', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 
            'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'pub_rec_bankruptcies']
filt_cat_cols = ['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status', 'loan_status', 'purpose', 'delinq_2yrs', 
            'inq_last_6mths', 'open_acc', 'total_acc', ]
filt_date_cols = ['last_pymnt_d']
filt_extra_cols = ['id', 'member_id']

# %%
loan_data1[filt_cat_cols]
# Out:
#              term grade sub_grade home_ownership verification_status  \
# 0       36 months     B        B2           RENT            Verified
# 1       60 months     C        C4           RENT     Source Verified
# 2       36 months     C        C5           RENT        Not Verified
# 3       36 months     C        C1           RENT     Source Verified
# 4       60 months     B        B5           RENT     Source Verified
# ...           ...   ...       ...            ...                 ...
# 39712   36 months     A        A4       MORTGAGE        Not Verified
# 39713   36 months     C        C1           RENT        Not Verified
# 39714   36 months     A        A4       MORTGAGE        Not Verified
# 39715   36 months     A        A2       MORTGAGE        Not Verified
# 39716   36 months     E        E2            OWN        Not Verified
#
#        loan_status             purpose  delinq_2yrs  inq_last_6mths  open_acc  \
# 0       Fully Paid         credit_card            0               1         3
# 1      Charged Off                 car            0               5         3
# 2       Fully Paid      small_business            0               2         2
# 3       Fully Paid               other            0               1        10
# 4          Current               other            0               0        15
# ...            ...                 ...          ...             ...       ...
# 39712   Fully Paid    home_improvement            0               0        13
# 39713   Fully Paid         credit_card            1               1         6
# 39714   Fully Paid  debt_consolidation            0               0        11
# 39715   Fully Paid               other            0               0        17
# 39716   Fully Paid  debt_consolidation            1               0         7
#
#        total_acc
# 0              9
# 1              4
# 2             10
# 3             37
# 4             38
# ...          ...
# 39712         40
# 39713          9
# 39714         20
# 39715         26
# 39716          8
#
# [39717 rows x 11 columns]

# %%
loan_data1[filt_date_cols]
# Out:
#       last_pymnt_d
# 0           Jan-15
# 1           Apr-13
# 2           Jun-14
# 3           Jan-15
# 4           May-16
# ...            ...
# 39712       Jul-10
# 39713       Jul-10
# 39714       Apr-08
# 39715       Jan-08
# 39716       Jun-10
#
# [39717 rows x 1 columns]

# %%
loan_data1[filt_extra_cols]
# Out:
#             id  member_id
# 0      1077501    1296599
# 1      1077430    1314167
# 2      1077175    1313524
# 3      1076863    1277178
# 4      1075358    1311748
# ...        ...        ...
# 39712    92187      92174
# 39713    90665      90607
# 39714    90395      90390
# 39715    90376      89243
# 39716    87023      86999
#
# [39717 rows x 2 columns]

# %%
loan_data1.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'home_ownership', 'annual_inc', 'verification_status', 'loan_status',
#        'purpose', 'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'revol_bal',
#        'revol_util', 'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt'],
#       dtype='object')

# %%
loan_data1.shape
# Out:
# (39717, 32)

# %%
loan_data1.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade home_ownership  annual_inc  \
# 0   10.65%       162.87     B        B2           RENT     24000.0
# 1   15.27%        59.83     C        C4           RENT     30000.0
# 2   15.96%        84.33     C        C5           RENT     12252.0
# 3   13.49%       339.31     C        C1           RENT     49200.0
# 4   12.69%        67.79     B        B5           RENT     80000.0
# 5    7.90%       156.46     A        A4           RENT     36000.0
# 6   15.96%       170.08     C        C5           RENT     47004.0
# 7   18.64%       109.43     E        E1           RENT     48000.0
# 8   21.28%       152.39     F        F2            OWN     40000.0
# 9   12.69%       121.45     B        B5           RENT     15000.0
#
#   verification_status  loan_status             purpose  delinq_2yrs  \
# 0            Verified   Fully Paid         credit_card            0
# 1     Source Verified  Charged Off                 car            0
# 2        Not Verified   Fully Paid      small_business            0
# 3     Source Verified   Fully Paid               other            0
# 4     Source Verified      Current               other            0
# 5     Source Verified   Fully Paid             wedding            0
# 6        Not Verified   Fully Paid  debt_consolidation            0
# 7     Source Verified   Fully Paid                 car            0
# 8     Source Verified  Charged Off      small_business            0
# 9            Verified  Charged Off               other            0
#
#    inq_last_6mths  open_acc  revol_bal revol_util  total_acc  out_prncp  \
# 0               1         3      13648     83.70%          9       0.00
# 1               5         3       1687      9.40%          4       0.00
# 2               2         2       2956     98.50%         10       0.00
# 3               1        10       5598        21%         37       0.00
# 4               0        15      27783     53.90%         38     524.06
# 5               3         9       7963     28.30%         12       0.00
# 6               1         7      17726     85.60%         11       0.00
# 7               2         4       8221     87.50%          4       0.00
# 8               2        11       5210     32.60%         13       0.00
# 9               0         2       9279     36.50%          3       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00   5863.155187          5833.84          5000.00
# 1           0.00   1008.710000          1008.71           456.46
# 2           0.00   3005.666844          3005.67          2400.00
# 3           0.00  12231.890000         12231.89         10000.00
# 4         524.06   3513.330000          3513.33          2475.94
# 5           0.00   5632.210000          5632.21          5000.00
# 6           0.00  10110.840000         10110.84          6985.61
# 7           0.00   3939.135294          3939.14          3000.00
# 8           0.00    646.020000           646.02           162.02
# 9           0.00   1476.190000          1469.34           673.48
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         863.16                0.00        0.00                     0.00
# 1         435.17                0.00      117.08                     1.11
# 2         605.67                0.00        0.00                     0.00
# 3        2214.92               16.97        0.00                     0.00
# 4        1037.39                0.00        0.00                     0.00
# 5         632.21                0.00        0.00                     0.00
# 6        3125.23                0.00        0.00                     0.00
# 7         939.14                0.00        0.00                     0.00
# 8         294.94                0.00      189.06                     2.09
# 9         533.42                0.00      269.29                     2.52
#
#   last_pymnt_d  last_pymnt_amnt
# 0       Jan-15           171.62
# 1       Apr-13           119.66
# 2       Jun-14           649.91
# 3       Jan-15           357.48
# 4       May-16            67.79
# 5       Jan-15           161.03
# 6       May-16          1313.76
# 7       Jan-15           111.34
# 8       Apr-12           152.39
# 9       Nov-12           121.45

# %%
##Drop rows where loan status is current
#As loan status current will determine if loan will be defaulted or not
loan_data2=loan_data1[~(loan_data1["loan_status"] == "Current")]
loan_data2.head(10)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0   1077501    1296599       5000         5000           4975.0   36 months
# 1   1077430    1314167       2500         2500           2500.0   60 months
# 2   1077175    1313524       2400         2400           2400.0   36 months
# 3   1076863    1277178      10000        10000          10000.0   36 months
# 5   1075269    1311441       5000         5000           5000.0   36 months
# 6   1069639    1304742       7000         7000           7000.0   60 months
# 7   1072053    1288686       3000         3000           3000.0   36 months
# 8   1071795    1306957       5600         5600           5600.0   60 months
# 9   1071570    1306721       5375         5375           5350.0   60 months
# 10  1070078    1305201       6500         6500           6500.0   60 months
#
#    int_rate  installment grade sub_grade home_ownership  annual_inc  \
# 0    10.65%       162.87     B        B2           RENT     24000.0
# 1    15.27%        59.83     C        C4           RENT     30000.0
# 2    15.96%        84.33     C        C5           RENT     12252.0
# 3    13.49%       339.31     C        C1           RENT     49200.0
# 5     7.90%       156.46     A        A4           RENT     36000.0
# 6    15.96%       170.08     C        C5           RENT     47004.0
# 7    18.64%       109.43     E        E1           RENT     48000.0
# 8    21.28%       152.39     F        F2            OWN     40000.0
# 9    12.69%       121.45     B        B5           RENT     15000.0
# 10   14.65%       153.45     C        C3            OWN     72000.0
#
#    verification_status  loan_status             purpose  delinq_2yrs  \
# 0             Verified   Fully Paid         credit_card            0
# 1      Source Verified  Charged Off                 car            0
# 2         Not Verified   Fully Paid      small_business            0
# 3      Source Verified   Fully Paid               other            0
# 5      Source Verified   Fully Paid             wedding            0
# 6         Not Verified   Fully Paid  debt_consolidation            0
# 7      Source Verified   Fully Paid                 car            0
# 8      Source Verified  Charged Off      small_business            0
# 9             Verified  Charged Off               other            0
# 10        Not Verified   Fully Paid  debt_consolidation            0
#
#     inq_last_6mths  open_acc  revol_bal revol_util  total_acc  out_prncp  \
# 0                1         3      13648     83.70%          9        0.0
# 1                5         3       1687      9.40%          4        0.0
# 2                2         2       2956     98.50%         10        0.0
# 3                1        10       5598        21%         37        0.0
# 5                3         9       7963     28.30%         12        0.0
# 6                1         7      17726     85.60%         11        0.0
# 7                2         4       8221     87.50%          4        0.0
# 8                2        11       5210     32.60%         13        0.0
# 9                0         2       9279     36.50%          3        0.0
# 10               2        14       4032     20.60%         23        0.0
#
#     out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0             0.0   5863.155187          5833.84          5000.00
# 1             0.0   1008.710000          1008.71           456.46
# 2             0.0   3005.666844          3005.67          2400.00
# 3             0.0  12231.890000         12231.89         10000.00
# 5             0.0   5632.210000          5632.21          5000.00
# 6             0.0  10110.840000         10110.84          6985.61
# 7             0.0   3939.135294          3939.14          3000.00
# 8             0.0    646.020000           646.02           162.02
# 9             0.0   1476.190000          1469.34           673.48
# 10            0.0   7678.017673          7678.02          6500.00
#
#     total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          863.16                0.00        0.00                     0.00
# 1          435.17                0.00      117.08                     1.11
# 2          605.67                0.00        0.00                     0.00
# 3         2214.92               16.97        0.00                     0.00
# 5          632.21                0.00        0.00                     0.00
# 6         3125.23                0.00        0.00                     0.00
# 7          939.14                0.00        0.00                     0.00
# 8          294.94                0.00      189.06                     2.09
# 9          533.42                0.00      269.29                     2.52
# 10        1178.02                0.00        0.00                     0.00
#
#    last_pymnt_d  last_pymnt_amnt
# 0        Jan-15           171.62
# 1        Apr-13           119.66
# 2        Jun-14           649.91
# 3        Jan-15           357.48
# 5        Jan-15           161.03
# 6        May-16          1313.76
# 7        Jan-15           111.34
# 8        Apr-12           152.39
# 9        Nov-12           121.45
# 10       Jun-13          1655.54

# %%
#loan_data1['revol_util'].plot(kind="hist")

# %%
#Convert Data type

# %%
#Check the data types of columns 
loan_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38577 entries, 0 to 39716
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       38577 non-null  int64
#  1   member_id                38577 non-null  int64
#  2   loan_amnt                38577 non-null  int64
#  3   funded_amnt              38577 non-null  int64
#  4   funded_amnt_inv          38577 non-null  float64
#  5   term                     38577 non-null  object
#  6   int_rate                 38577 non-null  object
#  7   installment              38577 non-null  float64
#  8   grade                    38577 non-null  object
#  9   sub_grade                38577 non-null  object
#  10  home_ownership           38577 non-null  object
#  11  annual_inc               38577 non-null  float64
#  12  verification_status      38577 non-null  object
#  13  loan_status              38577 non-null  object
#  14  purpose                  38577 non-null  object
#  15  delinq_2yrs              38577 non-null  int64
#  16  inq_last_6mths           38577 non-null  int64
#  17  open_acc                 38577 non-null  int64
#  18  revol_bal                38577 non-null  int64
#  19  revol_util               38527 non-null  object
#  20  total_acc                38577 non-null  int64
#  21  out_prncp                38577 non-null  float64
#  22  out_prncp_inv            38577 non-null  float64
#  23  total_pymnt              38577 non-null  float64
#  24  total_pymnt_inv          38577 non-null  float64
#  25  total_rec_prncp          38577 non-null  float64
#  26  total_rec_int            38577 non-null  float64
#  27  total_rec_late_fee       38577 non-null  float64
#  28  recoveries               38577 non-null  float64
#  29  collection_recovery_fee  38577 non-null  float64
#  30  last_pymnt_d             38506 non-null  object
#  31  last_pymnt_amnt          38577 non-null  float64
# dtypes: float64(13), int64(9), object(10)
# memory usage: 9.7+ MB

# %%
loan_data2.head(10)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0   1077501    1296599       5000         5000           4975.0   36 months
# 1   1077430    1314167       2500         2500           2500.0   60 months
# 2   1077175    1313524       2400         2400           2400.0   36 months
# 3   1076863    1277178      10000        10000          10000.0   36 months
# 5   1075269    1311441       5000         5000           5000.0   36 months
# 6   1069639    1304742       7000         7000           7000.0   60 months
# 7   1072053    1288686       3000         3000           3000.0   36 months
# 8   1071795    1306957       5600         5600           5600.0   60 months
# 9   1071570    1306721       5375         5375           5350.0   60 months
# 10  1070078    1305201       6500         6500           6500.0   60 months
#
#    int_rate  installment grade sub_grade home_ownership  annual_inc  \
# 0    10.65%       162.87     B        B2           RENT     24000.0
# 1    15.27%        59.83     C        C4           RENT     30000.0
# 2    15.96%        84.33     C        C5           RENT     12252.0
# 3    13.49%       339.31     C        C1           RENT     49200.0
# 5     7.90%       156.46     A        A4           RENT     36000.0
# 6    15.96%       170.08     C        C5           RENT     47004.0
# 7    18.64%       109.43     E        E1           RENT     48000.0
# 8    21.28%       152.39     F        F2            OWN     40000.0
# 9    12.69%       121.45     B        B5           RENT     15000.0
# 10   14.65%       153.45     C        C3            OWN     72000.0
#
#    verification_status  loan_status             purpose  delinq_2yrs  \
# 0             Verified   Fully Paid         credit_card            0
# 1      Source Verified  Charged Off                 car            0
# 2         Not Verified   Fully Paid      small_business            0
# 3      Source Verified   Fully Paid               other            0
# 5      Source Verified   Fully Paid             wedding            0
# 6         Not Verified   Fully Paid  debt_consolidation            0
# 7      Source Verified   Fully Paid                 car            0
# 8      Source Verified  Charged Off      small_business            0
# 9             Verified  Charged Off               other            0
# 10        Not Verified   Fully Paid  debt_consolidation            0
#
#     inq_last_6mths  open_acc  revol_bal revol_util  total_acc  out_prncp  \
# 0                1         3      13648     83.70%          9        0.0
# 1                5         3       1687      9.40%          4        0.0
# 2                2         2       2956     98.50%         10        0.0
# 3                1        10       5598        21%         37        0.0
# 5                3         9       7963     28.30%         12        0.0
# 6                1         7      17726     85.60%         11        0.0
# 7                2         4       8221     87.50%          4        0.0
# 8                2        11       5210     32.60%         13        0.0
# 9                0         2       9279     36.50%          3        0.0
# 10               2        14       4032     20.60%         23        0.0
#
#     out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0             0.0   5863.155187          5833.84          5000.00
# 1             0.0   1008.710000          1008.71           456.46
# 2             0.0   3005.666844          3005.67          2400.00
# 3             0.0  12231.890000         12231.89         10000.00
# 5             0.0   5632.210000          5632.21          5000.00
# 6             0.0  10110.840000         10110.84          6985.61
# 7             0.0   3939.135294          3939.14          3000.00
# 8             0.0    646.020000           646.02           162.02
# 9             0.0   1476.190000          1469.34           673.48
# 10            0.0   7678.017673          7678.02          6500.00
#
#     total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          863.16                0.00        0.00                     0.00
# 1          435.17                0.00      117.08                     1.11
# 2          605.67                0.00        0.00                     0.00
# 3         2214.92               16.97        0.00                     0.00
# 5          632.21                0.00        0.00                     0.00
# 6         3125.23                0.00        0.00                     0.00
# 7          939.14                0.00        0.00                     0.00
# 8          294.94                0.00      189.06                     2.09
# 9          533.42                0.00      269.29                     2.52
# 10        1178.02                0.00        0.00                     0.00
#
#    last_pymnt_d  last_pymnt_amnt
# 0        Jan-15           171.62
# 1        Apr-13           119.66
# 2        Jun-14           649.91
# 3        Jan-15           357.48
# 5        Jan-15           161.03
# 6        May-16          1313.76
# 7        Jan-15           111.34
# 8        Apr-12           152.39
# 9        Nov-12           121.45
# 10       Jun-13          1655.54

# %%
for col in filt_num_cols:
    print(col,loan_data1[col].describe())
    print("********************************")
# Out:
# loan_amnt count    39717.000000
# mean     11219.443815
# std       7456.670694
# min        500.000000
# 25%       5500.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64
# ********************************
# funded_amnt count    39717.000000
# mean     10947.713196
# std       7187.238670
# min        500.000000
# 25%       5400.000000
# 50%       9600.000000
# 75%      15000.000000
# max      35000.000000
# Name: funded_amnt, dtype: float64
# ********************************
# funded_amnt_inv count    39717.000000
# mean     10397.448868
# std       7128.450439
# min          0.000000
# 25%       5000.000000
# 50%       8975.000000
# 75%      14400.000000
# max      35000.000000
# Name: funded_amnt_inv, dtype: float64
# ********************************
# int_rate count      39717
# unique       371
# top       10.99%
# freq         956
# Name: int_rate, dtype: object
# ********************************
# installment count    39717.000000
# mean       324.561922
# std        208.874874
# min         15.690000
# 25%        167.020000
# 50%        280.220000
# 75%        430.780000
# max       1305.190000
# Name: installment, dtype: float64
# ********************************
# annual_inc count    3.971700e+04
# mean     6.896893e+04
# std      6.379377e+04
# min      4.000000e+03
# 25%      4.040400e+04
# 50%      5.900000e+04
# 75%      8.230000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64
# ********************************
# revol_bal count     39717.000000
# mean      13382.528086
# std       15885.016641
# min           0.000000
# 25%        3703.000000
# 50%        8850.000000
# 75%       17058.000000
# max      149588.000000
# Name: revol_bal, dtype: float64
# ********************************
# revol_util count     39667
# unique     1089
# top          0%
# freq        977
# Name: revol_util, dtype: object
# ********************************
# out_prncp count    39717.000000
# mean        51.227887
# std        375.172839
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       6311.470000
# Name: out_prncp, dtype: float64
# ********************************
# out_prncp_inv count    39717.000000
# mean        50.989768
# std        373.824457
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       6307.370000
# Name: out_prncp_inv, dtype: float64
# ********************************
# total_pymnt count    39717.000000
# mean     12153.596544
# std       9042.040766
# min          0.000000
# 25%       5576.930000
# 50%       9899.640319
# 75%      16534.433040
# max      58563.679930
# Name: total_pymnt, dtype: float64
# ********************************
# total_pymnt_inv count    39717.000000
# mean     11567.149118
# std       8942.672613
# min          0.000000
# 25%       5112.310000
# 50%       9287.150000
# 75%      15798.810000
# max      58563.680000
# Name: total_pymnt_inv, dtype: float64
# ********************************
# total_rec_prncp count    39717.000000
# mean      9793.348813
# std       7065.522127
# min          0.000000
# 25%       4600.000000
# 50%       8000.000000
# 75%      13653.260000
# max      35000.020000
# Name: total_rec_prncp, dtype: float64
# ********************************
# total_rec_int count    39717.000000
# mean      2263.663172
# std       2608.111964
# min          0.000000
# 25%        662.180000
# 50%       1348.910000
# 75%       2833.400000
# max      23563.680000
# Name: total_rec_int, dtype: float64
# ********************************
# total_rec_late_fee count    39717.000000
# mean         1.363015
# std          7.289979
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        180.200000
# Name: total_rec_late_fee, dtype: float64
# ********************************
# recoveries count    39717.000000
# mean        95.221624
# std        688.744771
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      29623.350000
# Name: recoveries, dtype: float64
# ********************************
# collection_recovery_fee count    39717.000000
# mean        12.406112
# std        148.671593
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       7002.190000
# Name: collection_recovery_fee, dtype: float64
# ********************************
# last_pymnt_amnt count    39717.000000
# mean      2678.826162
# std       4447.136012
# min          0.000000
# 25%        218.680000
# 50%        546.140000
# 75%       3293.160000
# max      36115.200000
# Name: last_pymnt_amnt, dtype: float64
# ********************************
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pub_rec_bankruptcies'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[383], line 2
#       1 for col in filt_num_cols:
# ----> 2     print(col,loan_data1[col].describe())
#       3     print("********************************")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'pub_rec_bankruptcies'

# %%
#Aanalyze all colums
for col in filt_cat_cols:
    print(col,loan_data1[col].value_counts())
    print("********************************")
# Out:
# term term
#  36 months    29096
#  60 months    10621
# Name: count, dtype: int64
# ********************************
# grade grade
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: count, dtype: int64
# ********************************
# sub_grade sub_grade
# B3    2917
# A4    2886
# A5    2742
# B5    2704
# B4    2512
# C1    2136
# B2    2057
# C2    2011
# B1    1830
# A3    1810
# C3    1529
# A2    1508
# D2    1348
# C4    1236
# C5    1186
# D3    1173
# A1    1139
# D4     981
# D1     931
# D5     874
# E1     763
# E2     656
# E3     553
# E4     454
# E5     416
# F1     329
# F2     249
# F3     185
# F4     168
# F5     118
# G1     104
# G2      78
# G4      56
# G3      48
# G5      30
# Name: count, dtype: int64
# ********************************
# home_ownership home_ownership
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER          98
# NONE            3
# Name: count, dtype: int64
# ********************************
# verification_status verification_status
# Not Verified       16921
# Verified           12809
# Source Verified     9987
# Name: count, dtype: int64
# ********************************
# loan_status loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64
# ********************************
# purpose purpose
# debt_consolidation    18641
# credit_card            5130
# other                  3993
# home_improvement       2976
# major_purchase         2187
# small_business         1828
# car                    1549
# wedding                 947
# medical                 693
# moving                  583
# vacation                381
# house                   381
# educational             325
# renewable_energy        103
# Name: count, dtype: int64
# ********************************
# delinq_2yrs delinq_2yrs
# 0     35405
# 1      3303
# 2       687
# 3       220
# 4        62
# 5        22
# 6        10
# 7         4
# 8         2
# 9         1
# 11        1
# Name: count, dtype: int64
# ********************************
# inq_last_6mths inq_last_6mths
# 0    19300
# 1    10971
# 2     5812
# 3     3048
# 4      326
# 5      146
# 6       64
# 7       35
# 8       15
# Name: count, dtype: int64
# ********************************
# open_acc open_acc
# 7     4018
# 6     3946
# 8     3936
# 9     3718
# 10    3223
# 5     3183
# 11    2746
# 4     2343
# 12    2273
# 13    1911
# 3     1493
# 14    1487
# 15    1177
# 16     940
# 17     741
# 2      605
# 18     533
# 19     396
# 20     289
# 21     244
# 22     143
# 23      97
# 24      81
# 25      55
# 26      34
# 28      25
# 27      22
# 30      15
# 29      13
# 31       7
# 34       5
# 32       4
# 35       4
# 33       3
# 36       2
# 39       1
# 38       1
# 44       1
# 41       1
# 42       1
# Name: count, dtype: int64
# ********************************
# total_acc total_acc
# 16    1471
# 15    1462
# 17    1457
# 14    1445
# 20    1428
#       ...
# 74       1
# 77       1
# 78       1
# 87       1
# 90       1
# Name: count, Length: 82, dtype: int64
# ********************************

# %%
filt_num_cols = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'annual_inc', 'revol_bal', 'revol_util', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 
            'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'pub_rec_bankruptcies']
filt_cat_cols = ['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status', 'loan_status', 'purpose', 'delinq_2yrs', 
            'inq_last_6mths', 'open_acc', 'total_acc', ]
filt_date_cols = ['last_pymnt_d']
filt_extra_cols = ['id', 'member_id']

# %%
##We need to check lona_status columns so doing more analysis with ther columns using groupby

# %%
#Data abalysis loan_status  and int_rate relationship
group_data =loan_data2.groupby('loan_status')['int_rate'].mean()
group_data
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:482, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     481     result_mask = result_mask[None, :]
# --> 482 res = self._call_cython_op(
#     483     values2d,
#     484     min_count=min_count,
#     485     ngroups=ngroups,
#     486     comp_ids=comp_ids,
#     487     mask=mask,
#     488     result_mask=result_mask,
#     489     **kwargs,
#     490 )
#     491 if res.shape[0] == 1:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '15.27%21.28%12.69%13.49%10.65%12.42%11.71%14.27%16.77%8.90%9.91%15.96%19.91%10.65%17.27%21.28%16.77%17.27%9.91%16.77%18.25%13.49%10.65%19.91%15.96%6.62%9.91%11.71%13.49%14.65%7.51%13.49%17.27%20.89%11.71%16.77%17.27%12.69%14.27%12.42%16.29%14.27%12.69%7.90%16.77%11.71%12.69%12.69%12.69%12.42%8.90%13.49%12.69%7.90%16.29%12.42%16.77%20.30%19.91%18.64%15.27%17.27%12.42%9.91%11.71%8.90%11.71%12.69%7.51%19.42%12.69%8.90%12.69%12.69%7.90%18.64%14.65%14.65%14.27%13.49%11.71%16.77%18.25%17.27%10.65%16.29%17.27%7.90%15.27%8.90%20.30%14.65%12.42%15.27%12.69%19.91%7.90%14.65%20.30%16.29%17.58%12.42%14.27%7.90%7.90%17.58%12.42%18.25%7.90%16.29%12.69%16.29%16.77%20.89%19.42%7.90%12.69%23.13%14.65%22.74%12.69%11.71%15.27%12.69%12.42%15.96%13.49%17.27%19.91%12.42%11.71%11.71%14.27%14.27%16.77%12.69%11.71%18.25%12.42%13.49%20.89%17.58%7.51%20.30%7.51%7.51%12.69%15.27%15.27%11.71%16.77%15.96%19.42%19.03%17.58%19.42%15.27%12.69%7.90%20.89%17.58%11.71%9.91%12.69%14.27%20.89%22.35%13.49%17.27%11.71%17.27%9.91%20.30%16.77%14.27%14.27%12.42%12.69%18.64%15.27%7.90%16.77%21.67%14.27%7.51%21.28%19.03%20.89%17.27%14.27%17.27%15.27%11.71%11.71%13.49%15.27%19.42%17.27%7.51%15.96%12.69%18.25%7.51%18.64%12.69%17.27%15.27%11.71%10.65%10.65%19.91%15.27%19.42%14.27%16.77%7.90%20.89%14.65%15.96%6.62%18.64%12.42%7.51%20.30%14.27%13.49%8.90%10.65%6.62%9.91%17.58%13.49%17.27%11.71%6.62%22.06%18.25%13.49%12.42%10.65%17.27%14.65%17.58%11.71%17.58%18.64%13.49%12.69%7.51%6.03%19.91%12.69%13.49%15.96%9.91%15.96%17.27%14.27%15.27%21.28%11.71%14.27%7.51%11.71%14.27%12.69%20.30%13.49%17.27%6.62%10.65%12.69%7.51%12.69%19.91%19.03%8.90%18.25%6.62%21.67%12.42%10.65%14.27%17.27%7.51%15.96%14.27%17.27%12.42%12.69%19.03%17.27%12.69%13.49%19.03%21.28%18.64%15.27%14.65%12.69%16.29%12.69%18.25%23.13%12.42%16.77%17.58%8.90%8.90%22.06%14.27%15.27%10.65%15.27%18.64%22.35%12.69%9.91%14.27%12.42%11.71%21.28%13.49%16.77%19.91%22.35%20.30%12.69%7.90%16.29%19.03%20.30%20.89%22.35%16.77%16.29%14.27%10.65%19.03%22.35%17.27%17.58%16.29%16.77%20.89%19.91%14.27%18.64%19.42%18.64%7.51%15.27%17.27%7.90%16.77%16.29%11.71%19.42%21.28%18.64%18.25%14.27%18.64%16.77%7.90%12.69%12.69%19.03%19.91%11.71%12.42%8.90%9.91%19.91%17.27%17.58%20.89%18.64%15.27%17.27%11.71%7.51%12.42%19.03%6.62%13.49%20.89%14.27%14.27%22.06%7.51%18.64%14.27%10.65%18.25%19.03%13.49%14.27%15.27%15.27%12.69%14.65%14.65%18.64%19.03%13.49%19.42%16.77%11.71%7.90%22.35%18.25%17.58%14.27%16.29%19.91%21.67%8.90%14.27%20.30%15.96%20.30%12.42%23.13%20.89%9.91%19.03%18.25%17.27%12.42%12.69%7.90%21.67%12.69%9.91%14.27%15.96%20.30%17.58%11.71%19.03%18.25%14.27%15.96%16.77%14.65%7.51%15.96%18.64%14.65%20.30%23.91%17.27%14.27%13.49%22.35%11.71%12.69%7.90%18.25%21.28%14.27%16.29%19.42%20.89%21.67%14.65%14.65%17.58%15.27%23.52%8.90%18.64%18.64%9.91%12.69%10.65%20.30%11.71%13.49%18.64%16.29%13.49%23.52%18.64%12.69%18.64%14.27%20.89%11.71%8.90%14.65%17.27%14.27%7.90%17.58%19.91%15.96%8.90%11.71%17.58%7.90%15.96%19.03%15.27%12.69%17.27%14.65%23.52%12.42%18.25%22.06%14.65%20.30%13.49%14.65%13.49%18.25%14.65%11.71%12.42%8.90%11.71%21.67%6.62%16.77%7.90%23.13%13.49%9.91%19.42%11.71%19.42%18.25%10.65%7.90%20.30%11.71%17.58%14.27%19.03%15.27%16.77%14.27%17.58%17.27%14.27%19.03%19.42%16.29%19.42%11.71%15.27%18.25%14.27%11.71%9.91%8.90%18.64%9.91%18.25%13.49%19.91%16.29%11.71%10.65%16.77%13.49%18.25%19.91%15.27%17.58%10.65%12.69%17.27%8.90%21.28%16.77%21.28%18.25%21.28%20.89%20.30%14.27%11.71%15.27%19.91%12.42%19.03%18.25%20.30%12.69%22.35%20.30%17.58%14.27%16.77%13.49%13.49%13.49%12.69%20.89%18.25%18.25%22.35%15.27%6.62%19.03%18.64%11.71%12.42%17.27%18.64%14.27%19.03%7.90%7.51%8.90%11.71%14.27%18.64%17.58%17.27%17.27%13.49%12.69%14.65%15.27%11.71%10.65%19.42%11.71%11.71%11.71%14.65%22.06%20.30%15.96%17.27%6.62%12.42%9.91%11.71%16.77%15.27%10.65%14.27%7.51%19.42%10.65%11.71%16.29%11.71%10.65%17.58%11.71%14.65%21.67%16.29%18.25%15.96%15.27%11.71%22.06%15.96%11.71%11.71%11.71%7.51%22.06%17.27%10.65%19.03%20. ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[387], line 2
#       1 #Data abalysis loan_status  and int_rate relationship
# ----> 2 group_data =loan_data2.groupby('loan_status')['int_rate'].mean()
#       3 group_data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:197, in SingleDataManager.grouped_reduce(self, func)
#     195 def grouped_reduce(self, func):
#     196     arr = self.array
# --> 197     res = func(arr)
#     198     index = default_index(len(res))
#     200     mgr = type(self).from_array(res, index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert 15.27%21.28%12.69%13.49%10.65%12.42%11.71%14.27%16.77%8.90%9.91%15.96%19.91%10.65%17.27%21.28%16.77%17.27%9.91%16.77%18.25%13.49%10.65%19.91%15.96%6.62%9.91%11.71%13.49%14.65%7.51%13.49%17.27%20.89%11.71%16.77%17.27%12.69%14.27%12.42%16.29%14.27%12.69%7.90%16.77%11.71%12.69%12.69%12.69%12.42%8.90%13.49%12.69%7.90%16.29%12.42%16.77%20.30%19.91%18.64%15.27%17.27%12.42%9.91%11.71%8.90%11.71%12.69%7.51%19.42%12.69%8.90%12.69%12.69%7.90%18.64%14.65%14.65%14.27%13.49%11.71%16.77%18.25%17.27%10.65%16.29%17.27%7.90%15.27%8.90%20.30%14.65%12.42%15.27%12.69%19.91%7.90%14.65%20.30%16.29%17.58%12.42%14.27%7.90%7.90%17.58%12.42%18.25%7.90%16.29%12.69%16.29%16.77%20.89%19.42%7.90%12.69%23.13%14.65%22.74%12.69%11.71%15.27%12.69%12.42%15.96%13.49%17.27%19.91%12.42%11.71%11.71%14.27%14.27%16.77%12.69%11.71%18.25%12.42%13.49%20.89%17.58%7.51%20.30%7.51%7.51%12.69%15.27%15.27%11.71%16.77%15.96%19.42%19.03%17.58%19.42%15.27%12.69%7.90%20.89%17.58%11.71%9.91%12.69%14.27%20.89%22.35%13.49%17.27%11.71%17.27%9.91%20.30%16.77%14.27%14.27%12.42%12.69%18.64%15.27%7.90%16.77%21.67%14.27%7.51%21.28%19.03%20.89%17.27%14.27%17.27%15.27%11.71%11.71%13.49%15.27%19.42%17.27%7.51%15.96%12.69%18.25%7.51%18.64%12.69%17.27%15.27%11.71%10.65%10.65%19.91%15.27%19.42%14.27%16.77%7.90%20.89%14.65%15.96%6.62%18.64%12.42%7.51%20.30%14.27%13.49%8.90%10.65%6.62%9.91%17.58%13.49%17.27%11.71%6.62%22.06%18.25%13.49%12.42%10.65%17.27%14.65%17.58%11.71%17.58%18.64%13.49%12.69%7.51%6.03%19.91%12.69%13.49%15.96%9.91%15.96%17.27%14.27%15.27%21.28%11.71%14.27%7.51%11.71%14.27%12.69%20.30%13.49%17.27%6.62%10.65%12.69%7.51%12.69%19.91%19.03%8.90%18.25%6.62%21.67%12.42%10.65%14.27%17.27%7.51%15.96%14.27%17.27%12.42%12.69%19.03%17.27%12.69%13.49%19.03%21.28%18.64%15.27%14.65%12.69%16.29%12.69%18.25%23.13%12.42%16.77%17.58%8.90%8.90%22.06%14.27%15.27%10.65%15.27%18.64%22.35%12.69%9.91%14.27%12.42%11.71%21.28%13.49%16.77%19.91%22.35%20.30%12.69%7.90%16.29%19.03%20.30%20.89%22.35%16.77%16.29%14.27%10.65%19.03%22.35%17.27%17.58%16.29%16.77%20.89%19.91%14.27%18.64%19.42%18.64%7.51%15.27%17.27%7.90%16.77%16.29%11.71%19.42%21.28%18.64%18.25%14.27%18.64%16.77%7.90%12.69%12.69%19.03%19.91%11.71%12.42%8.90%9.91%19.91%17.27%17.58%20.89%18.64%15.27%17.27%11.71%7.51%12.42%19.03%6.62%13.49%20.89%14.27%14.27%22.06%7.51%18.64%14.27%10.65%18.25%19.03%13.49%14.27%15.27%15.27%12.69%14.65%14.65%18.64%19.03%13.49%19.42%16.77%11.71%7.90%22.35%18.25%17.58%14.27%16.29%19.91%21.67%8.90%14.27%20.30%15.96%20.30%12.42%23.13%20.89%9.91%19.03%18.25%17.27%12.42%12.69%7.90%21.67%12.69%9.91%14.27%15.96%20.30%17.58%11.71%19.03%18.25%14.27%15.96%16.77%14.65%7.51%15.96%18.64%14.65%20.30%23.91%17.27%14.27%13.49%22.35%11.71%12.69%7.90%18.25%21.28%14.27%16.29%19.42%20.89%21.67%14.65%14.65%17.58%15.27%23.52%8.90%18.64%18.64%9.91%12.69%10.65%20.30%11.71%13.49%18.64%16.29%13.49%23.52%18.64%12.69%18.64%14.27%20.89%11.71%8.90%14.65%17.27%14.27%7.90%17.58%19.91%15.96%8.90%11.71%17.58%7.90%15.96%19.03%15.27%12.69%17.27%14.65%23.52%12.42%18.25%22.06%14.65%20.30%13.49%14.65%13.49%18.25%14.65%11.71%12.42%8.90%11.71%21.67%6.62%16.77%7.90%23.13%13.49%9.91%19.42%11.71%19.42%18.25%10.65%7.90%20.30%11.71%17.58%14.27%19.03%15.27%16.77%14.27%17.58%17.27%14.27%19.03%19.42%16.29%19.42%11.71%15.27%18.25%14.27%11.71%9.91%8.90%18.64%9.91%18.25%13.49%19.91%16.29%11.71%10.65%16.77%13.49%18.25%19.91%15.27%17.58%10.65%12.69%17.27%8.90%21.28%16.77%21.28%18.25%21.28%20.89%20.30%14.27%11.71%15.27%19.91%12.42%19.03%18.25%20.30%12.69%22.35%20.30%17.58%14.27%16.77%13.49%13.49%13.49%12.69%20.89%18.25%18.25%22.35%15.27%6.62%19.03%18.64%11.71%12.42%17.27%18.64%14.27%19.03%7.90%7.51%8.90%11.71%14.27%18.64%17.58%17.27%17.27%13.49%12.69%14.65%15.27%11.71%10.65%19.42%11.71%11.71%11.71%14.65%22.06%20.30%15.96%17.27%6.62%12.42%9.91%11.71%16.77%15.27%10.65%14.27%7.51%19.42%10.65%11.71%16.29%11.71%10.65%17.58%11.71%14.65%21.67%16.29%18.25%15.96%15.27%11.71%22.06%15.96%11.71%11.71%11.71%7.51%22.06%17.27%10.65%19.03%20.30%12.69%15.27%22.0 ...

# %%
#result BY comparing loan status int_rate it can be seen people who were charged off took high interest rate then the people who paid fully

# %%
#Data abalysis loan_status  and loan_amnt relationship
group_data =loan_data2.groupby('loan_status')['loan_amnt'].mean()
group_data
# Out:
# loan_status
# Charged Off    12104.385108
# Fully Paid     10866.455994
# Name: loan_amnt, dtype: float64

# %%
#result BY comparing loan status wrtloan_amnt it can be seen people who were charged off ttook high loan then the people who paid fully

# %%
#Data abalysis loan_status  and funded_amnt relationship
group_data =loan_data2.groupby('loan_status')['funded_amnt'].mean()
group_data
# Out:
# loan_status
# Charged Off    11753.398792
# Fully Paid     10618.520486
# Name: funded_amnt, dtype: float64

# %%
#result BY comparing loan status wrtloan_amnt it can be seen people who were charged off have higher funded_amnt then the people who paid fully

# %%
#Data abalysis loan_status  and revol_bal
group_data =loan_data2.groupby('loan_status')['revol_bal'].mean()
group_data
# Out:
# loan_status
# Charged Off    13514.243647
# Fully Paid     13251.107739
# Name: revol_bal, dtype: float64

# %%
#result BY comparing loan status wrt revol_bal no conclusion can be made

# %%
#comparing loan status wrt annual income of person
group_data =loan_data2.groupby('loan_status')['annual_inc'].mean()
group_data
# Out:
# loan_status
# Charged Off    62427.298034
# Fully Paid     69862.503328
# Name: annual_inc, dtype: float64

# %%
#result BY comparing loan status wrt annual income of person it can be seen people who were charged off
#were having having lesser income than the fully paid

# %%
#Data abalysis loan_status  and annual total_pymnt
group_data =loan_data2.groupby('loan_status')['out_prncp'].mean()
group_data
# Out:
# loan_status
# Charged Off    0.0
# Fully Paid     0.0
# Name: out_prncp, dtype: float64

# %%
#Result BY comparing loan status wrt annual income of person it can be seen people who were charged off
#were having having lesser income than the fully paid

# %%
#Data abalysis loan_status  and annual installment
group_data =loan_data2.groupby('loan_status')['installment'].mean()
group_data
# Out:
# loan_status
# Charged Off    336.175006
# Fully Paid     320.125232
# Name: installment, dtype: float64

# %%
###BY comparing loan status wrt annual installment it can be seen people who were charged off
#took home loan for longer duration

# %%
#Data abalysis loan_status  and total_rec_late_fee

# %%
group_data =loan_data2.groupby('loan_status')['total_rec_late_fee'].mean()
group_data
# Out:
# loan_status
# Charged Off    4.291692
# Fully Paid     0.869452
# Name: total_rec_late_fee, dtype: float64

# %%
###BY comparing loan status wrt annual installment it can be seen people who were charged off
defaulted the payment frequently and  total_rec_late_fee is very high
# Out:
#   Cell In[405], line 2
#     defaulted the payment frequently and  total_rec_late_fee is very high
#               ^
# SyntaxError: invalid syntax

# %%
##getting error
##group_data =loan_data2.groupby('loan_status')['revol_util'].mean()
##group_data

# %%
group_data =loan_data2.groupby('loan_status')['int_rate'].mean()
group_data

# %%
group_data =loan_data2.groupby('loan_status')['total_rec_late_fee'].mean()
group_data
# Out:
# loan_status
# Charged Off    4.186577
# Fully Paid     0.843616
# Name: total_rec_late_fee, dtype: float64

# %%
##Analyze groupby datat= for loan status and term
#group_data =loan_data2.groupby(['loan_status','term']).size().unstack(fill_value=0)

# %%
group_data
# Out:
# loan_status
# Charged Off    4.291692
# Fully Paid     0.869452
# Name: total_rec_late_fee, dtype: float64

# %%
group_data =loan_data2.groupby(['loan_status','grade']).size().unstack(fill_value=0)
group_data
# Out:
# grade           A      B     C     D     E    F    G
# loan_status
# Charged Off   602   1425  1347  1118   715  319  101
# Fully Paid   9443  10250  6487  3967  1948  657  198

# %%
group_data =loan_data2.groupby(['loan_status','home_ownership']).size().unstack(fill_value=0)
group_data
# Out:
# home_ownership  MORTGAGE  NONE  OTHER   OWN   RENT
# loan_status
# Charged Off         2327     0     18   443   2839
# Fully Paid         14694     3     80  2532  15641

# %%
#3no specific analysis can be made

# %%
group_data =loan_data2.groupby(['loan_status','int_rate']).size().unstack(fill_value=0)
group_data
# Out:
# int_rate     10.00%  10.01%  10.08%  10.14%  10.20%  10.25%  10.28%  10.33%  \
# loan_status
# Charged Off      31       1       7       1       3      22       3       1
# Fully Paid      218       6      41       9      15     196      18       8
#
# int_rate     10.36%  10.37%  10.38%  10.39%  10.46%  10.51%  10.59%  10.62%  \
# loan_status
# Charged Off      32      51      23       5       1       3      47      23
# Fully Paid      218     416     196      44       6      19     311     205
#
# int_rate     10.64%  10.65%  10.71%  10.74%  10.75%  10.78%  10.83%  10.91%  \
# loan_status
# Charged Off       0      46       8      33      26       4       5       3
# Fully Paid        2     357      35     278     224      12      25      14
#
# int_rate     10.95%  10.96%  10.99%  11.03%  11.09%  11.11%  11.12%  11.14%  \
# loan_status
# Charged Off       9       2      95      10       2      36      30      22
# Fully Paid       69      12     818      40       3     295     229     184
#
# int_rate     11.22%  11.26%  11.28%  11.34%  11.36%  11.41%  11.46%  11.48%  \
# loan_status
# Charged Off       3      12       8       6      25       0       6      19
# Fully Paid       12      79      10      35     222       7      19     164
#
# int_rate     11.49%  11.54%  11.58%  11.59%  11.63%  11.66%  11.71%  11.72%  \
# loan_status
# Charged Off     127       3      13       1       2       8      91       1
# Fully Paid      663       9      86       8       6      30     468       8
#
# int_rate     11.78%  11.83%  11.86%  11.89%  11.91%  11.97%  11.99%  12.04%  \
# loan_status
# Charged Off       5      23      55      19       1       8      76       0
# Fully Paid       21     210     336     135      10      29     407       7
#
# int_rate     12.09%  12.12%  12.17%  12.18%  12.21%  12.22%  12.23%  12.29%  \
# loan_status
# Charged Off       3       3       5      29      19       1      31       8
# Fully Paid       15       2       5     174     150      12     103      28
#
# int_rate     12.36%  12.41%  12.42%  12.49%  12.53%  12.54%  12.61%  12.62%  \
# loan_status
# Charged Off       3       5      55       4      44       0      35       0
# Fully Paid        5      15     348       5     283       5     146       3
#
# int_rate     12.67%  12.68%  12.69%  12.72%  12.73%  12.80%  12.84%  12.86%  \
# loan_status
# Charged Off       1      44      72       0      24       3      19       0
# Fully Paid        4     207     379      16     163       5     114       8
#
# int_rate     12.87%  12.92%  12.98%  12.99%  13.04%  13.06%  13.11%  13.12%  \
# loan_status
# Charged Off      24       8      16      69       1      34      26       1
# Fully Paid      152      18     100     340      16     185     151       2
#
# int_rate     13.16%  13.17%  13.22%  13.23%  13.24%  13.30%  13.35%  13.36%  \
# loan_status
# Charged Off      23       0      19      37       7       4      20       2
# Fully Paid      108       6     123     226      22       4     107       6
#
# int_rate     13.43%  13.47%  13.48%  13.49%  13.55%  13.57%  13.61%  13.62%  \
# loan_status
# Charged Off      33      13      23     127       5      17      37       0
# Fully Paid      112     111     129     622      13     118     254       3
#
# int_rate     13.67%  13.72%  13.75%  13.79%  13.80%  13.84%  13.85%  13.87%  \
# loan_status
# Charged Off       3      19       2      18      24       1      19       3
# Fully Paid       14      97       3      93     107       1     111      11
#
# int_rate     13.92%  13.93%  13.98%  13.99%  14.07%  14.09%  14.11%  14.12%  \
# loan_status
# Charged Off      17       2      46      56       1       7      20       0
# Fully Paid      104       1     238     185       1      61      71       3
#
# int_rate     14.17%  14.18%  14.22%  14.25%  14.26%  14.27%  14.30%  14.35%  \
# loan_status
# Charged Off      26       1      21       0      22      74       1      12
# Fully Paid       96       8      97       2     103     270       4     108
#
# int_rate     14.38%  14.42%  14.46%  14.50%  14.54%  14.59%  14.61%  14.62%  \
# loan_status
# Charged Off       1      12      23       1      14      20      15       2
# Fully Paid        4      72      84       7      61      93      77       0
#
# int_rate     14.65%  14.67%  14.70%  14.72%  14.74%  14.75%  14.79%  14.82%  \
# loan_status
# Charged Off      41       0       1      13      11       0      41       0
# Fully Paid      157       1       1      99      54       3     136       6
#
# int_rate     14.83%  14.84%  14.88%  14.91%  14.93%  14.96%  15.01%  15.05%  \
# loan_status
# Charged Off      10      17       1      36       2      31       2      12
# Fully Paid       79     103       1     134       5     183       0      47
#
# int_rate     15.07%  15.13%  15.20%  15.21%  15.23%  15.25%  15.27%  15.28%  \
# loan_status
# Charged Off       0       0      19      45      42       1      52      23
# Fully Paid        2       4      48     142     158       3     133     124
#
# int_rate     15.31%  15.33%  15.37%  15.38%  15.45%  15.57%  15.58%  15.62%  \
# loan_status
# Charged Off      17      22       3       1       0      15      42      29
# Fully Paid       74      80      40       1       3      64     143     142
#
# int_rate     15.65%  15.68%  15.70%  15.76%  15.83%  15.88%  15.95%  15.96%  \
# loan_status
# Charged Off      38       9      12       0       0       0      35      33
# Fully Paid      170      29      68       3       2       4     164     134
#
# int_rate     15.99%  16.00%  16.01%  16.02%  16.07%  16.08%  16.11%  16.15%  \
# loan_status
# Charged Off      59      17       0      34       8       3       2       1
# Fully Paid      200      78       1     115      49       0       4       0
#
# int_rate     16.20%  16.29%  16.32%  16.33%  16.35%  16.40%  16.45%  16.49%  \
# loan_status
# Charged Off       0      33      44       1       8      38      45      61
# Fully Paid        1     109     154       1      36     102     117     157
#
# int_rate     16.59%  16.63%  16.69%  16.70%  16.71%  16.77%  16.82%  16.89%  \
# loan_status
# Charged Off       1       4       5      10       0      71      31      57
# Fully Paid        4       9      45      24       1     223     101     125
#
# int_rate     16.95%  16.96%  17.03%  17.04%  17.06%  17.14%  17.15%  17.19%  \
# loan_status
# Charged Off       4       0       1       6       9      25       1      22
# Fully Paid       12       1       1      20      25      82       1      88
#
# int_rate     17.26%  17.27%  17.34%  17.39%  17.43%  17.44%  17.46%  17.49%  \
# loan_status
# Charged Off       2      54       0       4       7       0       1      59
# Fully Paid        9     115       1      11      24       1       0     114
#
# int_rate     17.51%  17.54%  17.56%  17.58%  17.74%  17.80%  17.88%  17.90%  \
# loan_status
# Charged Off      19       0      29      41       6       7      13       1
# Fully Paid       45       1      77     107      12      12      53       1
#
# int_rate     17.93%  17.99%  18.07%  18.09%  18.17%  18.21%  18.25%  18.30%  \
# loan_status
# Charged Off      18      40       1       2       4       1      62      10
# Fully Paid       61      88       7       7      22       4     145      48
#
# int_rate     18.36%  18.39%  18.43%  18.49%  18.53%  18.54%  18.62%  18.64%  \
# loan_status
# Charged Off       0      40       4       0       1       5      11      40
# Fully Paid        1      94       9       3       3      15      38      81
#
# int_rate     18.67%  18.72%  18.78%  18.79%  18.84%  18.91%  18.99%  19.03%  \
# loan_status
# Charged Off      11       1       0      28       0       3       6      36
# Fully Paid       31       0       4      68       3       5      24      66
#
# int_rate     19.04%  19.13%  19.16%  19.29%  19.36%  19.39%  19.41%  19.42%  \
# loan_status
# Charged Off      15       2       1      29       8       1       8      28
# Fully Paid       17       9       2      75      23       3      17      63
#
# int_rate     19.47%  19.66%  19.69%  19.74%  19.79%  19.82%  19.91%  20.03%  \
# loan_status
# Charged Off       3       3      28      11       4       1      32       4
# Fully Paid        4       6      60      19       8       4      44       9
#
# int_rate     20.11%  20.16%  20.17%  20.20%  20.25%  20.30%  20.40%  20.48%  \
# loan_status
# Charged Off       8       3       1       1      22      31       1       8
# Fully Paid       17       9       2       1      47      46       2      14
#
# int_rate     20.52%  20.53%  20.62%  20.69%  20.77%  20.85%  20.86%  20.89%  \
# loan_status
# Charged Off       1       2      15       1       2       2       1      29
# Fully Paid        0      10      31       2       8      13       2      27
#
# int_rate     20.90%  20.99%  21.14%  21.21%  21.22%  21.27%  21.28%  21.36%  \
# loan_status
# Charged Off       6       9       1       1       3       1      19      16
# Fully Paid        5      37       3       3       4      12      19      22
#
# int_rate     21.48%  21.59%  21.64%  21.67%  21.74%  21.82%  22.06%  22.11%  \
# loan_status
# Charged Off       0       2       2      14      18       1      13       9
# Fully Paid        1       6       1      23      11       1      14      17
#
# int_rate     22.35%  22.48%  22.64%  22.74%  22.85%  22.94%  23.13%  23.22%  \
# loan_status
# Charged Off      12       7       1       9       4       1       5       1
# Fully Paid       11       9       0       6       4       0       3       8
#
# int_rate     23.52%  23.59%  23.91%  24.11%  24.40%  5.42%  5.79%  5.99%  \
# loan_status
# Charged Off       4       1       2       1       1     20     16     19
# Fully Paid        2       3       7       2       0    553    394    328
#
# int_rate     6.00%  6.03%  6.17%  6.39%  6.54%  6.62%  6.76%  6.91%  6.92%  \
# loan_status
# Charged Off      0      5     10      1     27     29      5     20      8
# Fully Paid      16    442    242     57    278    367    163    283    196
#
# int_rate     6.99%  7.05%  7.12%  7.14%  7.29%  7.37%  7.40%  7.42%  7.43%  \
# loan_status
# Charged Off     14      3      0     19     17      1      1      1      1
# Fully Paid     322     20      7    322    380     30     71      6     25
#
# int_rate     7.49%  7.51%  7.66%  7.68%  7.74%  7.75%  7.88%  7.90%  7.91%  \
# loan_status
# Charged Off     39     54     23      3      3      3     38     49      1
# Fully Paid     612    733    269     86    150     20    687    525     13
#
# int_rate     8.00%  8.07%  8.32%  8.38%  8.49%  8.59%  8.63%  8.70%  8.88%  \
# loan_status
# Charged Off     10      1      3      1     49     11      1      0     19
# Fully Paid     181     22     41     17    385    170     37     12    141
#
# int_rate     8.90%  8.94%  9.01%  9.07%  9.20%  9.25%  9.32%  9.33%  9.38%  \
# loan_status
# Charged Off     36     24      2      2      1     10      9      3      2
# Fully Paid     350    270     10     13     10    129    175     11     19
#
# int_rate     9.45%  9.51%  9.62%  9.63%  9.64%  9.67%  9.70%  9.76%  9.83%  \
# loan_status
# Charged Off      4      1     21     40      4      0      0     11      0
# Fully Paid      33      8    165    338     14      7      8     54      8
#
# int_rate     9.88%  9.91%  9.96%  9.99%
# loan_status
# Charged Off      9     35      2     58
# Fully Paid     172    322     17    532

# %%
##No specific analyiss can be made

# %%
group_data =loan_data2.groupby(['loan_status','purpose']).size().unstack(fill_value=0)
group_data
# Out:
# purpose       car  credit_card  debt_consolidation  educational  \
# loan_status
# Charged Off   160          542                2767           56
# Fully Paid   1339         4485               15288          269
#
# purpose      home_improvement  house  major_purchase  medical  moving  other  \
# loan_status
# Charged Off               347     59             222      106      92    633
# Fully Paid               2528    308            1928      575     484   3232
#
# purpose      renewable_energy  small_business  vacation  wedding
# loan_status
# Charged Off                19             475        53       96
# Fully Paid                 83            1279       322      830

# %%
##Result it can be seen people who were charged off took loan for longer term

# %%
filt_num_cols = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'annual_inc', 'revol_bal', 'revol_util', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 
            'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'pub_rec_bankruptcies']
filt_cat_cols = ['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status', 'loan_status', 'purpose', 'delinq_2yrs', 
            'inq_last_6mths', 'open_acc', 'total_acc', ]
filt_date_cols = ['last_pymnt_d']
filt_extra_cols = ['id', 'member_id']

# %%
##Data analysis using the plot

# %%
#Make plot

# %%
import pandas as pd
import numpy as np

##
import seaborn as sns
import matplotlib.pyplot as plt

###Extra
import warnings
warnings.filterwarnings('ignore')

# %%
#Do univariante analysis and check central tendency and ouliers
for columns in filt_num_cols:
    sns.boxplot(x=loan_data2[columns])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[420], line 3
#       1 #Do univariante analysis and check central tendency and ouliers
#       2 for columns in filt_num_cols:
# ----> 3     sns.boxplot(x=loan_data2[columns])
#       4     plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:785, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
# --> 785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:544, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     541         raise ValueError(err)
#     543 # Figure out the plotting orientation
# --> 544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#     548 # Option 2a:
#     549 # We are plotting a single set of data
#     550 # ------------------------------------
#     551 if x is None or y is None:
#     552
#     553     # Determine where the data are
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1601, in infer_orient(x, y, orient, require_numeric)
#    1599         warnings.warn(single_var_warning.format("Vertical", "x"))
#    1600     if require_numeric and x_type != "numeric":
# -> 1601         raise TypeError(nonnumeric_dv_error.format("Horizontal", "x"))
#    1602     return "h"
#    1604 elif str(orient).startswith("v"):
#
# TypeError: Horizontal orientation requires numeric `x` variable.

# %%
#Univariante analysis for funded_amant_inv
sns.boxplot(x=loan_data2['funded_amnt_inv'])
plt.show()

# %%
#Univariante analysis for annual income
sns.boxplot(x=loan_data2['annual_inc'])
plt.show()

# %%
sns.boxplot(x=loan_data2['total_acc'])
plt.show()

# %%
#as there are outlier in ananual income need to remove outlier 
percentile_95 =loan_data2['annual_inc'].quantile(0.95)
percentile_95
loan_data2 =loan_data2[loan_data2['annual_inc'] < percentile_95]
loan_data2
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 5      1075269    1311441       5000         5000           5000.0
# ...        ...        ...        ...          ...              ...
# 39711    92402      92390       5000         5000            700.0
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade home_ownership  \
# 0       36 months   10.65%       162.87     B        B2           RENT
# 1       60 months   15.27%        59.83     C        C4           RENT
# 2       36 months   15.96%        84.33     C        C5           RENT
# 3       36 months   13.49%       339.31     C        C1           RENT
# 5       36 months    7.90%       156.46     A        A4           RENT
# ...           ...      ...          ...   ...       ...            ...
# 39711   36 months    8.70%       158.30     B        B1       MORTGAGE
# 39712   36 months    8.07%        78.42     A        A4       MORTGAGE
# 39713   36 months   10.28%       275.38     C        C1           RENT
# 39714   36 months    8.07%       156.84     A        A4       MORTGAGE
# 39716   36 months   13.75%       255.43     E        E2            OWN
#
#        annual_inc verification_status  loan_status             purpose  \
# 0         24000.0            Verified   Fully Paid         credit_card
# 1         30000.0     Source Verified  Charged Off                 car
# 2         12252.0        Not Verified   Fully Paid      small_business
# 3         49200.0     Source Verified   Fully Paid               other
# 5         36000.0     Source Verified   Fully Paid             wedding
# ...           ...                 ...          ...                 ...
# 39711     75000.0        Not Verified   Fully Paid         credit_card
# 39712    110000.0        Not Verified   Fully Paid    home_improvement
# 39713     18000.0        Not Verified   Fully Paid         credit_card
# 39714    100000.0        Not Verified   Fully Paid  debt_consolidation
# 39716     22000.0        Not Verified   Fully Paid  debt_consolidation
#
#        delinq_2yrs  inq_last_6mths  open_acc  revol_bal revol_util  total_acc  \
# 0                0               1         3      13648     83.70%          9
# 1                0               5         3       1687      9.40%          4
# 2                0               2         2       2956     98.50%         10
# 3                0               1        10       5598        21%         37
# 5                0               3         9       7963     28.30%         12
# ...            ...             ...       ...        ...        ...        ...
# 39711            0               0        10      66033        23%         29
# 39712            0               0        13       7274     13.10%         40
# 39713            1               1         6       8847     26.90%          9
# 39714            0               0        11       9698     19.40%         20
# 39716            1               0         7       4175     51.50%          8
#
#        out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  \
# 0            0.0            0.0   5863.155187          5833.84
# 1            0.0            0.0   1008.710000          1008.71
# 2            0.0            0.0   3005.666844          3005.67
# 3            0.0            0.0  12231.890000         12231.89
# 5            0.0            0.0   5632.210000          5632.21
# ...          ...            ...           ...              ...
# 39711        0.0            0.0   5698.603286           797.80
# 39712        0.0            0.0   2822.969293          1213.88
# 39713        0.0            0.0   9913.491822          1020.51
# 39714        0.0            0.0   5272.161128          1397.12
# 39716        0.0            0.0   9195.263334           980.83
#
#        total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  \
# 0              5000.00         863.16                0.00        0.00
# 1               456.46         435.17                0.00      117.08
# 2              2400.00         605.67                0.00        0.00
# 3             10000.00        2214.92               16.97        0.00
# 5              5000.00         632.21                0.00        0.00
# ...                ...            ...                 ...         ...
# 39711          5000.00         698.60                0.00        0.00
# 39712          2500.00         322.97                0.00        0.00
# 39713          8500.00        1413.49                0.00        0.00
# 39714          5000.00         272.16                0.00        0.00
# 39716          7500.00        1695.26                0.00        0.00
#
#        collection_recovery_fee last_pymnt_d  last_pymnt_amnt
# 0                         0.00       Jan-15           171.62
# 1                         1.11       Apr-13           119.66
# 2                         0.00       Jun-14           649.91
# 3                         0.00       Jan-15           357.48
# 5                         0.00       Jan-15           161.03
# ...                        ...          ...              ...
# 39711                     0.00       Jul-10           159.83
# 39712                     0.00       Jul-10            80.90
# 39713                     0.00       Jul-10           281.94
# 39714                     0.00       Apr-08             0.00
# 39716                     0.00       Jun-10           256.59
#
# [36642 rows x 32 columns]

# %%
sns.boxplot(x=loan_data2['annual_inc'])
plt.show()

# %%
#draw historgram for Univariant analysis
sns.histplot(x=loan_data2['annual_inc'])
plt.show()

# %%
loan_data2['dti']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dti'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[427], line 1
# ----> 1 loan_data2['dti']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'dti'

# %%
#num_cols=["loan_amnt","funded_amnt","funded_amnt_inv","annual_inc","revol_bal","revol_util","total_acc","total_pymnt","total_pymnt_inv","total_rec_int" ]
for i in filt_num_cols:
    sns.histplot(x=loan_data2[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pub_rec_bankruptcies'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[428], line 3
#       1 #num_cols=["loan_amnt","funded_amnt","funded_amnt_inv","annual_inc","revol_bal","revol_util","total_acc","total_pymnt","total_pymnt_inv","total_rec_int" ]
#       2 for i in filt_num_cols:
# ----> 3     sns.histplot(x=loan_data2[i])
#       4     plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'pub_rec_bankruptcies'

# %%
#draw univariante analysis of categorical columns

# %%
cat_cols=["term","installment","home_ownership","loan_status","purpose", "verification_status"]

# %%
sns.countplot(x=loan_data2['term'])
plt.show()

# %%
sns.countplot(x=loan_data2['home_ownership'])
plt.show()

# %%
#Univariant Analysis verification staus
sns.countplot(x=loan_data2['verification_status'])
plt.show()

# %%
#Univariant Analysis 
sns.countplot(x=loan_data2['purpose'])
plt.show()

# %%
sns.scatterplot(x=loan_data2['annual_inc'])
plt.show()

# %%
##Bivariante analysis

# %%
num_cols=["loan_amnt","funded_amnt","funded_amnt_inv","annual_inc",'int_rate', "revol_bal","revol_util","total_acc","total_pymnt","total_pymnt_inv","total_rec_int" ]
##Bi Variante Analysis
for i in filt_num_cols:
  sns.boxplot(x=loan_data2["loan_status"],y=loan_data2[i])
  plt.show()

# %%
sns.boxplot(x=loan_data2["loan_status"],y=loan_data2['int_rate'])
plt.show()

# %%
##Result of box plot of two columns

# %%
1)Loan amount given to charged off were higher then loan amount to people who paid fully
2)Funded amount given to charged off were higher then loan amount to people who paid fully
3)Annual income of people were less for people who were charged off than those who paid fully
4)Intereset rate of people were higher for people who were charged off 
5)Total payment made charged off were lesse for people who were charged off
6)

# %%
#sns.scatterplot(x=loan_data2['int_rate'],y=loan_data2["loan_amnt"],)
#plt.show()
